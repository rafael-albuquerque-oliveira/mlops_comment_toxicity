# %%
import pandas as pd
import tensorflow as tf
import os
import numpy as np

# %%
train_df = pd.read_csv('data/jigsaw-toxic-comment-classification-challenge/train.csv.zip')

# %%
train_df.sample(10)
# Out:
#                       id                                       comment_text  \
# 26126   45227b30766dcca3  The images originate with the coat of arms dep...
# 34165   5b2f9e2a5df4d8ac  Your right it the summary is incorrect I found...
# 149253  599a668d2bb78f85  The project page was in rather bad condition d...
# 50683   878888cd204d3bdb  Henry Pym \nThe battle over the lead seems to ...
# 129060  b234d9ec33a529a0  Fuck You Danish hater! \n\nFuck you arsehole m...
# 102975  270fcc2b7feb4d38  "\n\nTake your time\nPlease take your time.  J...
# 5070    0d71dbc6b2f480ec  Any suggestions for appropriate punishments sh...
# 1549    042c43958c0415e1  Query on your deletion \n\nHello you deleted m...
# 83348   deffdc135852d864  The illusion of western objectivity is just th...
# 58831   9d90a8093b2f1b56  81.102.15.200\n\nSince I received no explanati...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# ...
